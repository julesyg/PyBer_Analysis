# %%
# %matplotlib inline

# %%
import matplotlib.pyplot as plt

# %%
# Set the x-axis to a list of strings for each month.
x_axis = ["Jan", "Feb", "Mar", "April", "May", "June", "July", "Aug", "Sept", "Oct", "Nov", "Dec"]

# Set the y-axis to a list of floats as the total fare in US dollars accumulated for each month.
y_axis = [10.02, 23.24, 39.20, 35.42, 32.34, 27.04, 43.82, 10.56, 11.85, 27.90, 20.71, 20.09]

# %%
plt.plot(x_axis, y_axis)

# %%
# Create the plot with ax.plt()
fig, ax = plt.subplots()
ax.plot(x_axis, y_axis)

# %%
# Create the plot with ax.plt()
fig = plt.figure()
ax = fig.add_subplot()
ax.plot(x_axis, y_axis)

# %%
ax = plt.axes()
ax.plot(x_axis, y_axis)

# %%
# Create the plot and add a label for the legend.
plt.plot(x_axis, y_axis, label='Boston')
# Create labels for the x and y axes.
plt.xlabel("Date")
plt.ylabel("Fare($)")
# Set the y limit between 0 and 45.
plt.ylim(0, 45)
# Create a title.
plt.title("PyBer Fare by Month")
# Add the legend.
plt.legend()

# %%
# Create the plot.
fig, ax = plt.subplots(x_axis, y_axis, marker="*", color="green", linewidth=2, label='Boston')
# Create labels for the x and y axes.
ax.set_xlabel("Date")
ax.set_ylabel("Fare($)")
# Set the y limit between 0 and 45.
ax.set_ylim(0, 45)
# Create a title.
ax.set_title("PyBer Fare by Month")
# Add a grid.
ax.grid()
# Add the legend.
ax.legend()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [12], in <cell line: 2>()
#       1 # Create the plot.
# ----> 2 fig, ax = plt.subplots(x_axis, y_axis, marker="*", color="green", linewidth=2, label='Boston')
#       3 # Create labels for the x and y axes.
#       4 ax.set_xlabel("Date")
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/matplotlib/pyplot.py:1455, in subplots(nrows, ncols, sharex, sharey, squeeze, subplot_kw, gridspec_kw, **fig_kw)
#    1321 def subplots(nrows=1, ncols=1, *, sharex=False, sharey=False, squeeze=True,
#    1322              subplot_kw=None, gridspec_kw=None, **fig_kw):
#    1323     """
#    1324     Create a figure and a set of subplots.
#    1325
#    (...)
#    1453
#    1454     """
# -> 1455     fig = figure(**fig_kw)
#    1456     axs = fig.subplots(nrows=nrows, ncols=ncols, sharex=sharex, sharey=sharey,
#    1457                        squeeze=squeeze, subplot_kw=subplot_kw,
#    1458                        gridspec_kw=gridspec_kw)
#    1459     return fig, axs
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/matplotlib/pyplot.py:808, in figure(num, figsize, dpi, facecolor, edgecolor, frameon, FigureClass, clear, **kwargs)
#     799 if len(allnums) == max_open_warning >= 1:
#     800     _api.warn_external(
#     801         f"More than {max_open_warning} figures have been opened. "
#     802         f"Figures created through the pyplot interface "
#    (...)
#     805         f"warning, see the rcParam `figure.max_open_warning`).",
#     806         RuntimeWarning)
# --> 808 manager = new_figure_manager(
#     809     num, figsize=figsize, dpi=dpi,
#     810     facecolor=facecolor, edgecolor=edgecolor, frameon=frameon,
#     811     FigureClass=FigureClass, **kwargs)
#     812 fig = manager.canvas.figure
#     813 if fig_label:
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/matplotlib/pyplot.py:327, in new_figure_manager(*args, **kwargs)
#     325 """Create a new figure manager instance."""
#     326 _warn_if_gui_out_of_main_thread()
# --> 327 return _get_backend_mod().new_figure_manager(*args, **kwargs)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/matplotlib_inline/backend_inline.py:27, in new_figure_manager(num, FigureClass, *args, **kwargs)
#      21 def new_figure_manager(num, *args, FigureClass=Figure, **kwargs):
#      22     """
#      23     Return a new figure manager for a new figure instance.
#      24
#      25     This function is part of the API expected by Matplotlib backends.
#      26     """
# ---> 27     return new_figure_manager_given_figure(num, FigureClass(*args, **kwargs))
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/matplotlib/figure.py:2292, in Figure.__init__(self, figsize, dpi, facecolor, edgecolor, linewidth, frameon, subplotpars, tight_layout, constrained_layout, layout, **kwargs)
#    2208 def __init__(self,
#    2209              figsize=None,
#    2210              dpi=None,
#    (...)
#    2220              **kwargs
#    2221              ):
#    2222     """
#    2223     Parameters
#    2224     ----------
#    (...)
#    2290         %(Figure:kwdoc)s
#    2291     """
# -> 2292     super().__init__(**kwargs)
#    2294     if layout is not None:
#    2295         if tight_layout is not None:
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/matplotlib/figure.py:216, in FigureBase.__init__(self, **kwargs)
#     214 self.stale = True
#     215 self.suppressComposite = None
# --> 216 self.set(**kwargs)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/matplotlib/artist.py:116, in Artist.__init_subclass__.<locals>.<lambda>(self, **kwargs)
#     108 if not hasattr(cls.set, '_autogenerated_signature'):
#     109     # Don't overwrite cls.set if the subclass or one of its parents
#     110     # has defined a set method set itself.
#     111     # If there was no explicit definition, cls.set is inherited from
#     112     # the hierarchy of auto-generated set methods, which hold the
#     113     # flag _autogenerated_signature.
#     114     return
# --> 116 cls.set = lambda self, **kwargs: Artist.set(self, **kwargs)
#     117 cls.set.__name__ = "set"
#     118 cls.set.__qualname__ = f"{cls.__qualname__}.set"
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/matplotlib/artist.py:1164, in Artist.set(self, **kwargs)
#    1159 def set(self, **kwargs):
#    1160     # docstring and signature are auto-generated via
#    1161     # Artist._update_set_signature_and_docstring() at the end of the
#    1162     # module.
#    1163     kwargs = cbook.normalize_kwargs(kwargs, self)
# -> 1164     return self.update(kwargs)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/matplotlib/artist.py:1064, in Artist.update(self, props)
#    1062             func = getattr(self, f"set_{k}", None)
#    1063             if not callable(func):
# -> 1064                 raise AttributeError(f"{type(self).__name__!r} object "
#    1065                                      f"has no property {k!r}")
#    1066             ret.append(func(v))
#    1067 if ret:
#
# AttributeError: 'Figure' object has no property 'marker'

# %%
# Set the x-axis to a list of strings for each month.
x_axis = ["Jan", "Feb", "Mar", "April", "May", "June", "July", "Aug", "Sept", "Oct", "Nov", "Dec"]

# Set the y-axis to a list of floats as the total fare in US dollars accumulated for each month.
y_axis = [10.02, 23.24, 39.20, 35.42, 32.34, 27.04, 43.82, 10.56, 11.85, 27.90, 20.71, 20.09]

# %%
# Create the plot
plt.bar(x_axis, y_axis)
# Out:
# <BarContainer object of 12 artists>

# %%
# Create the plot.
plt.bar(x_axis, y_axis, color="green", label='Boston')
# Create labels for the x and y axes.
plt.xlabel("Date")
plt.ylabel("Fare($)")
# Create a title.
plt.title("PyBer Fare by Month")
# Add the legend.
plt.legend()

# %%
# Create the plot
plt.barh(x_axis, y_axis)
# Out:
# <BarContainer object of 12 artists>

# %%
# Create the plot
plt.barh(y_axis, x_axis)
# Out:
# <BarContainer object of 12 artists>

# %%
# Create the plot.
plt.barh(x_axis, y_axis)
plt.gca().invert_yaxis()

# %%
# Create the plot.
ax.bar(x_axis, y_axis, color="magenta", label='Boston')
# Create labels for the x and y axes.
ax.set_xlabel("Date")
ax.set_ylabel("Fare($)")
# Create a title.
ax.set_title("PyBer Fare by Month")
# Add the legend.
ax.legend()

# %%
# Set the x-axis to a list of strings for each month.
x_axis = ["Jan", "Feb", "Mar", "April", "May", "June", "July", "Aug", "Sept", "Oct", "Nov", "Dec"]

# Set the y-axis to a list of floats as the total fare in US dollars accumulated for each month.
y_axis = [10.02, 23.24, 39.20, 35.42, 32.34, 27.04, 43.82, 10.56, 11.85, 27.90, 20.71, 20.09]

# %%
# Create the plot with ax.plt()
fig, ax = plt.subplots()
ax.bar(x_axis, y_axis)
# Out:
# <BarContainer object of 12 artists>

# %%
# Create the plot with ax.plt()
fig, ax = plt.subplots()
ax.barh(x_axis, y_axis)
# Out:
# <BarContainer object of 12 artists>

# %%
# Create the plot with ax.plt()
fig, ax = plt.subplots()
ax.barh(y_axis, x_axis)
# Out:
# <BarContainer object of 12 artists>

# %%
fig, ax = plt.subplots(x_axis, y_axis, color = "cyan", label='Chicago')
ax.barh(x_axis, y_axis)
ax.set_xlabel('Fare($)')
ax.set_ylabel('Month')
ax.set_title('PyBer Fare by Month')
ax.legend()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [29], in <cell line: 1>()
# ----> 1 fig, ax = plt.subplots(x_axis, y_axis, color = "cyan", label='Chicago')
#       2 ax.barh(x_axis, y_axis)
#       3 ax.set_xlabel('Fare($)')
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/matplotlib/pyplot.py:1455, in subplots(nrows, ncols, sharex, sharey, squeeze, subplot_kw, gridspec_kw, **fig_kw)
#    1321 def subplots(nrows=1, ncols=1, *, sharex=False, sharey=False, squeeze=True,
#    1322              subplot_kw=None, gridspec_kw=None, **fig_kw):
#    1323     """
#    1324     Create a figure and a set of subplots.
#    1325
#    (...)
#    1453
#    1454     """
# -> 1455     fig = figure(**fig_kw)
#    1456     axs = fig.subplots(nrows=nrows, ncols=ncols, sharex=sharex, sharey=sharey,
#    1457                        squeeze=squeeze, subplot_kw=subplot_kw,
#    1458                        gridspec_kw=gridspec_kw)
#    1459     return fig, axs
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/matplotlib/pyplot.py:808, in figure(num, figsize, dpi, facecolor, edgecolor, frameon, FigureClass, clear, **kwargs)
#     799 if len(allnums) == max_open_warning >= 1:
#     800     _api.warn_external(
#     801         f"More than {max_open_warning} figures have been opened. "
#     802         f"Figures created through the pyplot interface "
#    (...)
#     805         f"warning, see the rcParam `figure.max_open_warning`).",
#     806         RuntimeWarning)
# --> 808 manager = new_figure_manager(
#     809     num, figsize=figsize, dpi=dpi,
#     810     facecolor=facecolor, edgecolor=edgecolor, frameon=frameon,
#     811     FigureClass=FigureClass, **kwargs)
#     812 fig = manager.canvas.figure
#     813 if fig_label:
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/matplotlib/pyplot.py:327, in new_figure_manager(*args, **kwargs)
#     325 """Create a new figure manager instance."""
#     326 _warn_if_gui_out_of_main_thread()
# --> 327 return _get_backend_mod().new_figure_manager(*args, **kwargs)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/matplotlib_inline/backend_inline.py:27, in new_figure_manager(num, FigureClass, *args, **kwargs)
#      21 def new_figure_manager(num, *args, FigureClass=Figure, **kwargs):
#      22     """
#      23     Return a new figure manager for a new figure instance.
#      24
#      25     This function is part of the API expected by Matplotlib backends.
#      26     """
# ---> 27     return new_figure_manager_given_figure(num, FigureClass(*args, **kwargs))
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/matplotlib/figure.py:2292, in Figure.__init__(self, figsize, dpi, facecolor, edgecolor, linewidth, frameon, subplotpars, tight_layout, constrained_layout, layout, **kwargs)
#    2208 def __init__(self,
#    2209              figsize=None,
#    2210              dpi=None,
#    (...)
#    2220              **kwargs
#    2221              ):
#    2222     """
#    2223     Parameters
#    2224     ----------
#    (...)
#    2290         %(Figure:kwdoc)s
#    2291     """
# -> 2292     super().__init__(**kwargs)
#    2294     if layout is not None:
#    2295         if tight_layout is not None:
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/matplotlib/figure.py:216, in FigureBase.__init__(self, **kwargs)
#     214 self.stale = True
#     215 self.suppressComposite = None
# --> 216 self.set(**kwargs)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/matplotlib/artist.py:116, in Artist.__init_subclass__.<locals>.<lambda>(self, **kwargs)
#     108 if not hasattr(cls.set, '_autogenerated_signature'):
#     109     # Don't overwrite cls.set if the subclass or one of its parents
#     110     # has defined a set method set itself.
#     111     # If there was no explicit definition, cls.set is inherited from
#     112     # the hierarchy of auto-generated set methods, which hold the
#     113     # flag _autogenerated_signature.
#     114     return
# --> 116 cls.set = lambda self, **kwargs: Artist.set(self, **kwargs)
#     117 cls.set.__name__ = "set"
#     118 cls.set.__qualname__ = f"{cls.__qualname__}.set"
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/matplotlib/artist.py:1164, in Artist.set(self, **kwargs)
#    1159 def set(self, **kwargs):
#    1160     # docstring and signature are auto-generated via
#    1161     # Artist._update_set_signature_and_docstring() at the end of the
#    1162     # module.
#    1163     kwargs = cbook.normalize_kwargs(kwargs, self)
# -> 1164     return self.update(kwargs)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/matplotlib/artist.py:1064, in Artist.update(self, props)
#    1062             func = getattr(self, f"set_{k}", None)
#    1063             if not callable(func):
# -> 1064                 raise AttributeError(f"{type(self).__name__!r} object "
#    1065                                      f"has no property {k!r}")
#    1066             ret.append(func(v))
#    1067 if ret:
#
# AttributeError: 'Figure' object has no property 'color'

# %%
# Set the x-axis to a list of strings for each month.
x_axis = ["Jan", "Feb", "Mar", "April", "May", "June", "July", "Aug", "Sept", "Oct", "Nov", "Dec"]

# Set the y-axis to a list of floats as the total fare in US dollars accumulated for each month.
y_axis = [10.02, 23.24, 39.20, 35.42, 32.34, 27.04, 43.82, 10.56, 11.85, 27.90, 20.71, 20.09]

# %%
plt.plot(x_axis, y_axis, 'o')

# %%
plt.scatter(x_axis, y_axis)

# %%
fig, ax = plt.scatter(x_axis, y_axis, color = "red")
ax.scatter(x, y, label = 'Chicago')
ax.set_xlabel('date')
ax.set_ylabel('fare($)')
ax.set_title("Pyberfares")
ax.legend()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [38], in <cell line: 1>()
# ----> 1 fig, ax = plt.scatter(x_axis, y_axis, color = "red")
#       2 ax.scatter(x, y, label = 'Chicago')
#       3 ax.set_xlabel('date')
#
# TypeError: cannot unpack non-iterable PathCollection object

# %%
plt.scatter(x_axis, y_axis, s=y_axis)

# %%
y_axis_larger = []
for data in y_axis:
  y_axis_larger.append(data*3)

# %%
plt.scatter(x_axis, y_axis, s=y_axis_larger)

# %%
plt.scatter(x_axis, y_axis, s = [i * 3 for i in y_axis])

# %%
fig, ax = plt.subplots()
ax.scatter(x_axis, y_axis)
